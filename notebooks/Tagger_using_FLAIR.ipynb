# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
import os
os.chdir('/gdrive/My Drive/DEFT_2/')
! ls
# Out:
# bilstm_crf			  dev.csv  runs		    transformer
# cache_dir			  model    task2_dev.csv
# data_merged.csv			  module   task2_train.csv
# Deft_Subtask_2_using_FLARE.ipynb  outputs  train.csv

# %%
# !pip install flair -q
# Out:
#      |████████████████████████████████| 143kB 37.4MB/s
#      |████████████████████████████████| 1.0MB 34.6MB/s
#      |████████████████████████████████| 235kB 49.8MB/s
#      |████████████████████████████████| 798kB 48.4MB/s
#      |████████████████████████████████| 501kB 45.5MB/s
#      |████████████████████████████████| 1.0MB 58.7MB/s
#      |████████████████████████████████| 3.7MB 51.5MB/s
#      |████████████████████████████████| 870kB 68.8MB/s
#   Building wheel for sqlitedict (setup.py) ... done
#   Building wheel for segtok (setup.py) ... done
#   Building wheel for langdetect (setup.py) ... done
#   Building wheel for mpld3 (setup.py) ... done
#   Building wheel for sacremoses (setup.py) ... done
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.

# %% [markdown]
# ## Some random tests

# %%
strs2 = '''The	data/source_txt/dev/t1_biology_0_0.txt	 126	 129	 B-Term	 T125	 0	 Direct-Defines
scientific	data/source_txt/dev/t1_biology_0_0.txt	 130	 140	 I-Term	 T125	 0	 Direct-Defines
method	data/source_txt/dev/t1_biology_0_0.txt	 141	 147	 I-Term	 T125	 0	 Direct-Defines
is	data/source_txt/dev/t1_biology_0_0.txt	 148	 150	 O	 -1	 -1	 0
a	data/source_txt/dev/t1_biology_0_0.txt	 151	 152	 B-Definition	 T126	 T125	 Direct-Defines
method	data/source_txt/dev/t1_biology_0_0.txt	 153	 159	 I-Definition	 T126	 T125	 Direct-Defines
of	data/source_txt/dev/t1_biology_0_0.txt	 160	 162	 I-Definition	 T126	 T125	 Direct-Defines
research	data/source_txt/dev/t1_biology_0_0.txt	 163	 171	 I-Definition	 T126	 T125	 Direct-Defines
with	data/source_txt/dev/t1_biology_0_0.txt	 172	 176	 I-Definition	 T126	 T125	 Direct-Defines
defined	data/source_txt/dev/t1_biology_0_0.txt	 177	 184	 I-Definition	 T126	 T125	 Direct-Defines
steps	data/source_txt/dev/t1_biology_0_0.txt	 185	 190	 I-Definition	 T126	 T125	 Direct-Defines
that	data/source_txt/dev/t1_biology_0_0.txt	 191	 195	 I-Definition	 T126	 T125	 Direct-Defines
include	data/source_txt/dev/t1_biology_0_0.txt	 196	 203	 I-Definition	 T126	 T125	 Direct-Defines
experiments	data/source_txt/dev/t1_biology_0_0.txt	 204	 215	 I-Definition	 T126	 T125	 Direct-Defines
and	data/source_txt/dev/t1_biology_0_0.txt	 216	 219	 I-Definition	 T126	 T125	 Direct-Defines
careful	data/source_txt/dev/t1_biology_0_0.txt	 220	 227	 I-Definition	 T126	 T125	 Direct-Defines
observation	data/source_txt/dev/t1_biology_0_0.txt	 228	 239	 I-Definition	 T126	 T125	 Direct-Defines
.	data/source_txt/dev/t1_biology_0_0.txt	 239	 240	 O	 -1	 -1	 0

38	data/source_txt/dev/t1_biology_0_0.txt	 3608	 3610	 O	 -1	 -1	 0
.	data/source_txt/dev/t1_biology_0_0.txt	 3610	 3611	 O	 -1	 -1	 0

The	data/source_txt/dev/t1_biology_0_0.txt	 3612	 3615	 O	 -1	 -1	 0
forest	data/source_txt/dev/t1_biology_0_0.txt	 3616	 3622	 O	 -1	 -1	 0
itself	data/source_txt/dev/t1_biology_0_0.txt	 3623	 3629	 O	 -1	 -1	 0
is	data/source_txt/dev/t1_biology_0_0.txt	 3630	 3632	 O	 -1	 -1	 0
an	data/source_txt/dev/t1_biology_0_0.txt	 3633	 3635	 O	 -1	 -1	 0
ecosystem	data/source_txt/dev/t1_biology_0_0.txt	 3636	 3645	 O	 -1	 -1	 0
.	data/source_txt/dev/t1_biology_0_0.txt	 3645	 3646	 O	 -1	 -1	 0

An	data/source_txt/dev/t1_biology_0_0.txt	 3655	 3657	 B-Term	 T162	 0	 Direct-Defines
ecosystem	data/source_txt/dev/t1_biology_0_0.txt	 3658	 3667	 I-Term	 T162	 0	 Direct-Defines
consists	data/source_txt/dev/t1_biology_0_0.txt	 3668	 3676	 B-Definition	 T163	 T162	 Direct-Defines
of	data/source_txt/dev/t1_biology_0_0.txt	 3677	 3679	 I-Definition	 T163	 T162	 Direct-Defines
all	data/source_txt/dev/t1_biology_0_0.txt	 3680	 3683	 I-Definition	 T163	 T162	 Direct-Defines
the	data/source_txt/dev/t1_biology_0_0.txt	 3684	 3687	 I-Definition	 T163	 T162	 Direct-Defines
living	data/source_txt/dev/t1_biology_0_0.txt	 3688	 3694	 I-Definition	 T163	 T162	 Direct-Defines
things	data/source_txt/dev/t1_biology_0_0.txt	 3695	 3701	 I-Definition	 T163	 T162	 Direct-Defines
in	data/source_txt/dev/t1_biology_0_0.txt	 3702	 3704	 I-Definition	 T163	 T162	 Direct-Defines
a	data/source_txt/dev/t1_biology_0_0.txt	 3705	 3706	 I-Definition	 T163	 T162	 Direct-Defines
particular	data/source_txt/dev/t1_biology_0_0.txt	 3707	 3717	 I-Definition	 T163	 T162	 Direct-Defines
area	data/source_txt/dev/t1_biology_0_0.txt	 3718	 3722	 I-Definition	 T163	 T162	 Direct-Defines
together	data/source_txt/dev/t1_biology_0_0.txt	 3723	 3731	 I-Definition	 T163	 T162	 Direct-Defines
with	data/source_txt/dev/t1_biology_0_0.txt	 3732	 3736	 I-Definition	 T163	 T162	 Direct-Defines
the	data/source_txt/dev/t1_biology_0_0.txt	 3737	 3740	 I-Definition	 T163	 T162	 Direct-Defines
abiotic	data/source_txt/dev/t1_biology_0_0.txt	 3741	 3748	 I-Definition	 T163	 T162	 Direct-Defines
,	data/source_txt/dev/t1_biology_0_0.txt	 3748	 3749	 I-Definition	 T163	 T162	 Direct-Defines
non	data/source_txt/dev/t1_biology_0_0.txt	 3750	 3753	 I-Definition	 T163	 T162	 Direct-Defines
-	data/source_txt/dev/t1_biology_0_0.txt	 3753	 3754	 I-Definition	 T163	 T162	 Direct-Defines
living	data/source_txt/dev/t1_biology_0_0.txt	 3754	 3760	 I-Definition	 T163	 T162	 Direct-Defines
parts	data/source_txt/dev/t1_biology_0_0.txt	 3761	 3766	 I-Definition	 T163	 T162	 Direct-Defines
of	data/source_txt/dev/t1_biology_0_0.txt	 3767	 3769	 I-Definition	 T163	 T162	 Direct-Defines
that	data/source_txt/dev/t1_biology_0_0.txt	 3770	 3774	 I-Definition	 T163	 T162	 Direct-Defines
environment	data/source_txt/dev/t1_biology_0_0.txt	 3775	 3786	 I-Definition	 T163	 T162	 Direct-Defines
such	data/source_txt/dev/t1_biology_0_0.txt	 3787	 3791	 I-Definition	 T163	 T162	 Direct-Defines
as	data/source_txt/dev/t1_biology_0_0.txt	 3792	 3794	 I-Definition	 T163	 T162	 Direct-Defines
nitrogen	data/source_txt/dev/t1_biology_0_0.txt	 3795	 3803	 I-Definition	 T163	 T162	 Direct-Defines
in	data/source_txt/dev/t1_biology_0_0.txt	 3804	 3806	 I-Definition	 T163	 T162	 Direct-Defines
the	data/source_txt/dev/t1_biology_0_0.txt	 3807	 3810	 I-Definition	 T163	 T162	 Direct-Defines
soil	data/source_txt/dev/t1_biology_0_0.txt	 3811	 3815	 I-Definition	 T163	 T162	 Direct-Defines
or	data/source_txt/dev/t1_biology_0_0.txt	 3816	 3818	 I-Definition	 T163	 T162	 Direct-Defines
rain	data/source_txt/dev/t1_biology_0_0.txt	 3819	 3823	 I-Definition	 T163	 T162	 Direct-Defines
water	data/source_txt/dev/t1_biology_0_0.txt	 3824	 3829	 I-Definition	 T163	 T162	 Direct-Defines
.	data/source_txt/dev/t1_biology_0_0.txt	 3829	 3830	 O	 -1	 -1	 0
'''

# f = open('test.csv','w')
# f.write(strs2)
# f.close()

import pandas as pd
df = pd.read_csv('task2_train.csv',sep='\t',header = None,skip_blank_lines=False )
df.head(5)
# Out:
#                                                     0
# 0                              Subject,Sentence,Label
# 1   0.deft," However , those fields of science rel...
# 2   0.deft," Deductive reasoning is a form of logi...
# 3   0.deft," A variable is any part of the experim...
# 4   0.deft," The control group contains every feat...
# 5   0.deft," 14 . In contrast , applied science or...
# 6   0.deft," There are usually acknowledgment and ...
# 7   0.deft," 23 . Finally , the conclusion section...
# 8   0.deft," 29 . Some cells contain aggregates of...
# 9   0.deft," 32 . In larger organisms , cells comb...
# 10  0.deft," Organs are collections of tissues gro...
# 11  0.deft," 35 . For instance , the circulatory s...
# 12  0.deft," Organisms are individual living entit...
# 13  0.deft," A phylogenetic tree is a diagram show...
# 14  0.deft," 44 . Another field of biological stud...
# 15  0.deft," 50 . An atom is composed of two regio...
# 16  0.deft," The number of protons determines an e...
# 17  0.deft," Isotopes are different forms of an el...
# 18  0.deft," Elements also have specific chemical ...
# 19  0.deft," This is known as the octet rule , whi...
# 20  0.deft," 68 . Chemical reactions occur when tw...
# 21  0.deft," 71 . Even though all of the reactants...
# 22  0.deft," 74 . In reversible reactions , reacta...
# 23  0.deft," This back and forth continues until a...
# 24  0.deft," 77 . Negative ions are formed by gain...
# 25  0.deft," 80 . Certain salts are referred to in...
# 26  0.deft," Like hydrogen bonds , van der Waals i...
# 27  0.deft," Specific heat is defined as the amoun...
# 28  0.deft," Even when below its boiling point , w...
# 29  0.deft," In cohesion , water molecules are att...
# 30  0.deft," 98 . This is because the water molecu...
# 31  0.deft," The macromolecules are a subset of or...
# 32  0.deft," 107 . So far , the hydrocarbons we ha...
# 33  0.deft," Another type of hydrocarbon , aromati...
# 34  0.deft," Molecules with other elements in thei...
# 35  0.deft," 116 . Most macromolecules are made fr...
# 36  0.deft," The monomers combine with each other ...
# 37  0.deft," 122 . Disaccharides ( di- = “ two ” )...
# 38  0.deft," 131 . When the hydrocarbon chain cont...
# 39  0.deft," Because of the hydrophobic nature of ...
# 40  0.deft," 137 . Proteins are one of the most ab...
# 41  0.deft," Changes in temperature , pH , and exp...
# 42  0.deft," 143 . The unique sequence of amino ac...
# 43  0.deft," 146 . The unique three - dimensional ...
# 44  0.deft," They carry the genetic blueprint of a...
# 45  0.deft," Cytosine , thymine , and uracil are c...
# 46  0.deft," Visible light passes and is bent thro...
# 47  0.deft," 167 . Like prokaryotes , eukaryotic c...
# 48  0.deft," A phospholipid is a lipid molecule wi...
# 49  0.deft," The nucleus ( plural = nuclei ) house...

# %%
strs = '''George N B-PER
Washington N I-PER
went V O
to P O
Washington N B-LOC

Sam N B-PER
Houston N I-PER
stayed V O
home N O'''

f = open('train.txt','w')
f.write(strs)
f.close()


from flair.data import Corpus
from flair.datasets import ColumnCorpus

# define columns
columns = {0: 'text', 1: 'pos', 2: 'ner'}

# this is the folder in which train, test and dev files reside
data_folder = '.'

# init a corpus using column format, data folder and the names of the train, dev and test files
corpus: Corpus = ColumnCorpus(data_folder, columns,
                              train_file='train.txt')
                              # test_file='test.txt',)
                              # dev_file='train.txt')
# Out:
# 2019-12-01 21:59:06,412 Reading data from .
# 2019-12-01 21:59:06,414 Train: train.txt
# 2019-12-01 21:59:06,415 Dev: None
# 2019-12-01 21:59:06,417 Test: None

# %%
len(corpus.train)
# Out:
# 1

# %%
print(corpus.train[0].to_tagged_string('ner'))
print(corpus.train[0].to_tagged_string('pos'))
# Out:
# George <B-PER> Washington <I-PER> went to Washington <B-LOC> Sam <B-PER> Houston <I-PER> stayed home
# George <N> Washington <N> went <V> to <P> Washington <N> Sam <N> Houston <N> stayed <V> home <N>

# %% [markdown]
# ## Loading the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Making the dataset ready for the first time

# %%
import pandas as pd
train = pd.read_csv('/content/drive/My Drive/Task2/task2_train.csv')
test = pd.read_csv('/content/drive/My Drive/Task2/task2_dev.csv')
train.head()
# Out:
#    Subject  ...                                              Label
# 0  biology  ...    O  O  B-Definition  I-Definition  I-Definiti...
# 1  biology  ...    B-Term  I-Term  O  B-Definition  I-Definitio...
# 2  biology  ...    B-Term  I-Term  O  B-Definition  I-Definitio...
# 3  biology  ...    B-Term  I-Term  I-Term  B-Definition  I-Defi...
# 4  biology  ...    O  O  O  O  O  B-Term  I-Term  O  B-Alias-Te...
#
# [5 rows x 3 columns]

# %%
# !python -m spacy download en_core_web_md
# !pip install -U tqdm
# Out:
# Collecting en_core_web_md==2.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.1.0/en_core_web_md-2.1.0.tar.gz (95.4MB)
#      |████████████████████████████████| 95.4MB 1.2MB/s
# Building wheels for collected packages: en-core-web-md
#   Building wheel for en-core-web-md (setup.py) ... done
#   Created wheel for en-core-web-md: filename=en_core_web_md-2.1.0-cp36-none-any.whl size=97126236 sha256=28e298121e4fa049e81d31ca1f580cd7926696fd9b93ce51a1f6f499c8e8694d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qv5g7g37/wheels/c1/2c/5f/fd7f3ec336bf97b0809c86264d2831c5dfb00fc2e239d1bb01
# Successfully built en-core-web-md
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-2.1.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')
# Collecting tqdm
#   Downloading https://files.pythonhosted.org/packages/47/55/fd9170ba08a1a64a18a7f8a18f088037316f2a41be04d2fe6ece5a653e8f/tqdm-4.43.0-py2.py3-none-any.whl (59kB)
#      |████████████████████████████████| 61kB 3.2MB/s
# Installing collected packages: tqdm
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
# Successfully installed tqdm-4.43.0

# %%
import spacy

#####################################################################
#       Two ways: 1. import spacy; spacy.load('en_core_web_md')     #
#                 2. import en_core_web_md; en_core_web_md.load()   #
#####################################################################

import en_core_web_md
nlp = en_core_web_md.load()
doc = nlp('Hello I am Aadarsh')
for token in doc:
  print(token.text,token.pos_, token.dep_, token.head.text)
# Out:
# Hello INTJ intj am
# I PRON nsubj am
# am VERB ROOT am
# Aadarsh PROPN attr am

# %%
train['Sentence'] = train['Sentence'].apply(lambda x: x.strip())
train['Label'] = train['Label'].apply(lambda x: x.strip())
test['Sentence'] = test['Sentence'].apply(lambda x: x.strip())
test['Label'] = test['Label'].apply(lambda x: x.strip())

# %%
# from tqdm import tqdm, tqdm_pandas
# tqdm_pandas(tqdm())
train['POS'] = train['Sentence'].apply(lambda x: ' '.join([token.pos_ for token in nlp(x)]))
test['POS'] = test['Sentence'].apply(lambda x: ' '.join([token.pos_ for token in nlp(x)]))

# %%
train.shape, test.shape
# Out:
# ((5569, 4), (273, 4))

# %%
train.head()
# Out:
#    Subject  ...                                                POS
# 0  biology  ...  ADV PUNCT DET NOUN ADP NOUN VERB ADP DET ADJ N...
# 1  biology  ...  ADJ NOUN VERB DET NOUN ADP ADJ NOUN DET VERB D...
# 2  biology  ...  DET NOUN VERB DET NOUN ADP DET NOUN DET VERB V...
# 3  biology  ...  DET NOUN NOUN VERB DET NOUN ADP DET ADJ NOUN A...
# 4  biology  ...  NUM PUNCT ADP NOUN PUNCT VERB NOUN CCONJ PUNCT...
#
# [5 rows x 4 columns]

# %%
f = open('/content/drive/My Drive/Task2/train.txt','w')
for row in train.iterrows():
  # print(row, row[1]['Sentence'], row[1]['POS'], row[1]['Label'])
  for text, pos, tag in zip(row[1]['Sentence'].split(),row[1]['POS'].split(),row[1]['Label'].split() ):
    f.write(f'{text}\t{pos}\t{tag}\n')
  f.write(f'\n')
f.close()

# %%
f = open('/content/drive/My Drive/Task2/test.txt','w')
for row in test.iterrows():
  # print(row, row[1]['Sentence'], row[1]['POS'], row[1]['Label'])
  for text, pos, tag in zip(row[1]['Sentence'].split(),row[1]['POS'].split(),row[1]['Label'].split() ):
    f.write(f'{text}\t{pos}\t{tag}\n')
  f.write(f'\n')
f.close()

# %% [markdown]
# ## Loading the corpus and training the model

# %%
from flair.data import Corpus
from flair.datasets import ColumnCorpus

# define columns
columns = {0: 'text', 1: 'pos', 2: 'ner'}

# this is the folder in which train, test and dev files reside
data_folder = '.'

# init a corpus using column format, data folder and the names of the train, dev and test files
corpus: Corpus = ColumnCorpus(data_folder, columns,
                              train_file='/content/drive/My Drive/Task2/train.txt',
                              test_file='/content/drive/My Drive/Task2/test.txt')
                              # test_file='train.txt')
# Out:
# 2020-02-28 12:20:02,564 Reading data from .
# 2020-02-28 12:20:02,565 Train: /content/drive/My Drive/Task2/train.txt
# 2020-02-28 12:20:02,566 Dev: None
# 2020-02-28 12:20:02,567 Test: /content/drive/My Drive/Task2/test.txt

# %%
# Something is wrong with the dataset . See the size in the dataframe and the corpus. Test file is fine but not the train one.
print(len(corpus.train))
print(len(corpus.dev))
print(len(corpus.test))

print(corpus.train[1].to_tagged_string('ner'))
print(corpus.train[1].to_tagged_string('pos'))
# Out:
# 5012
# 557
# 273
# Perception <B-Definition> of <I-Definition> frequency <I-Definition> is called pitch <B-Term> .
# Perception <NOUN> of <ADP> frequency <NOUN> is <VERB> called <VERB> pitch <NOUN> . <PUNCT>

# %%
from flair.data import Corpus
from flair.datasets import WNUT_17
from flair.embeddings import TokenEmbeddings, WordEmbeddings, StackedEmbeddings, FlairEmbeddings
from typing import List

# 1. get the corpus
# corpus: Corpus = WNUT_17().downsample(0.1)
print(corpus)

# 2. what tag do we want to predict?
tag_type = 'ner'

# 3. make the tag dictionary from the corpus
tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)
print(tag_dictionary.idx2item)

# 4. initialize embeddings
embedding_types: List[TokenEmbeddings] = [

    WordEmbeddings('glove'),

    # comment in this line to use character embeddings
    # CharacterEmbeddings(),

    # comment in these lines to use flair embeddings
    FlairEmbeddings('news-forward'),
    FlairEmbeddings('news-backward'),
]

embeddings: StackedEmbeddings = StackedEmbeddings(embeddings=embedding_types)

# 5. initialize sequence tagger
from flair.models import SequenceTagger

tagger: SequenceTagger = SequenceTagger(hidden_size=256,
                                        embeddings=embeddings,
                                        tag_dictionary=tag_dictionary,
                                        tag_type=tag_type,
                                        use_crf=True)
# Out:
# Corpus: 5012 train + 557 dev + 273 test sentences
# [b'<unk>', b'O', b'B-Term', b'I-Term', b'B-Alias-Term', b'B-Definition', b'I-Definition', b'I-Alias-Term', b'B-Qualifier', b'B-Referential-Term', b'I-Qualifier', b'B-Referential-Definition', b'B-Definition-frag', b'I-Definition-frag', b'I-Referential-Term', b'B-Secondary-Definition', b'I-Secondary-Definition', b'I-Referential-Definition', b'B-Term-frag', b'B-Alias-Term-frag', b'I-Term-frag', b'<START>', b'<STOP>']
# 2020-02-28 12:20:06,006 https://s3.eu-central-1.amazonaws.com/alan-nlp/resources/embeddings/glove.gensim.vectors.npy not found in cache, downloading to /tmp/tmp1o6bu450
# 100%|██████████| 160000128/160000128 [00:26<00:00, 6035394.27B/s]
# 2020-02-28 12:20:33,207 copying /tmp/tmp1o6bu450 to cache at /root/.flair/embeddings/glove.gensim.vectors.npy
# 2020-02-28 12:20:33,415 removing temp file /tmp/tmp1o6bu450
# 2020-02-28 12:20:34,606 https://s3.eu-central-1.amazonaws.com/alan-nlp/resources/embeddings/glove.gensim not found in cache, downloading to /tmp/tmpxdm_lm87
# 100%|██████████| 21494764/21494764 [00:02<00:00, 9652112.34B/s]
# 2020-02-28 12:20:37,469 copying /tmp/tmpxdm_lm87 to cache at /root/.flair/embeddings/glove.gensim
# 2020-02-28 12:20:37,490 removing temp file /tmp/tmpxdm_lm87
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2020-02-28 12:20:39,702 https://s3.eu-central-1.amazonaws.com/alan-nlp/resources/embeddings-v0.4.1/big-news-forward--h2048-l1-d0.05-lr30-0.25-20/news-forward-0.4.1.pt not found in cache, downloading to /tmp/tmp362y34g5
# 100%|██████████| 73034624/73034624 [00:05<00:00, 12322703.29B/s]
# 2020-02-28 12:20:46,317 copying /tmp/tmp362y34g5 to cache at /root/.flair/embeddings/news-forward-0.4.1.pt
# 2020-02-28 12:20:46,398 removing temp file /tmp/tmp362y34g5
# 2020-02-28 12:20:57,336 https://s3.eu-central-1.amazonaws.com/alan-nlp/resources/embeddings-v0.4.1/big-news-backward--h2048-l1-d0.05-lr30-0.25-20/news-backward-0.4.1.pt not found in cache, downloading to /tmp/tmpr_o_aow9
# 100%|██████████| 73034575/73034575 [00:05<00:00, 12398082.65B/s]
# 2020-02-28 12:21:03,883 copying /tmp/tmpr_o_aow9 to cache at /root/.flair/embeddings/news-backward-0.4.1.pt
# 2020-02-28 12:21:03,955 removing temp file /tmp/tmpr_o_aow9

# %%
# 6. initialize trainer
from flair.trainers import ModelTrainer

trainer: ModelTrainer = ModelTrainer(tagger, corpus)

# 7. start training
trainer.train('resources/taggers/example-ner',
              learning_rate=0.1,
              mini_batch_size=32,
              max_epochs=150 )

# 8. plot weight traces (optional)
from flair.visual.training_curves import Plotter
plotter = Plotter()
plotter.plot_weights('resources/taggers/example-ner/weights.txt')
# Out:
# Corpus: 5012 train + 557 dev + 273 test sentences
# [b'<unk>', b'O', b'B-Term', b'I-Term', b'B-Definition', b'I-Definition', b'B-Referential-Term', b'B-Qualifier', b'I-Qualifier', b'B-Alias-Term', b'I-Alias-Term', b'B-Referential-Definition', b'I-Referential-Definition', b'B-Term-frag', b'I-Term-frag', b'I-Referential-Term', b'B-Secondary-Definition', b'I-Secondary-Definition', b'B-Definition-frag', b'I-Definition-frag', b'B-Alias-Term-frag', b'<START>', b'<STOP>']
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2019-12-02 05:50:35,490 ----------------------------------------------------------------------------------------------------
# 2019-12-02 05:50:35,492 Model: "SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): WordEmbeddings('glove')
#     (list_embedding_1): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#         (decoder): Linear(in_features=2048, out_features=300, bias=True)
#       )
#     )
#     (list_embedding_2): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#         (decoder): Linear(in_features=2048, out_features=300, bias=True)
#       )
#     )
#   )
#   (word_dropout): WordDropout(p=0.05)
#   (locked_dropout): LockedDropout(p=0.5)
#   (embedding2nn): Linear(in_features=4196, out_features=4196, bias=True)
#   (rnn): LSTM(4196, 256, batch_first=True, bidirectional=True)
#   (linear): Linear(in_features=512, out_features=23, bias=True)
# )"
# 2019-12-02 05:50:35,493 ----------------------------------------------------------------------------------------------------
# 2019-12-02 05:50:35,494 Corpus: "Corpus: 5012 train + 557 dev + 273 test sentences"
# 2019-12-02 05:50:35,495 ----------------------------------------------------------------------------------------------------
# 2019-12-02 05:50:35,496 Parameters:
# 2019-12-02 05:50:35,496  - learning_rate: "0.1"
# 2019-12-02 05:50:35,497  - mini_batch_size: "32"
# 2019-12-02 05:50:35,498  - patience: "3"
# 2019-12-02 05:50:35,499  - anneal_factor: "0.5"
# 2019-12-02 05:50:35,500  - max_epochs: "150"
# 2019-12-02 05:50:35,501  - shuffle: "True"
# 2019-12-02 05:50:35,502  - train_with_dev: "False"
# 2019-12-02 05:50:35,503  - batch_growth_annealing: "False"
# 2019-12-02 05:50:35,504 ----------------------------------------------------------------------------------------------------
# 2019-12-02 05:50:35,504 Model training base path: "resources/taggers/example-ner"
# 2019-12-02 05:50:35,505 ----------------------------------------------------------------------------------------------------
# 2019-12-02 05:50:35,506 Device: cuda:0
# 2019-12-02 05:50:35,507 ----------------------------------------------------------------------------------------------------
# 2019-12-02 05:50:35,507 Embeddings storage mode: cpu
# 2019-12-02 05:50:35,509 ----------------------------------------------------------------------------------------------------
# 2019-12-02 05:50:36,436 epoch 1 - iter 0/157 - loss 89.12234497 - samples/sec: 519.22
# 2019-12-02 05:50:48,194 epoch 1 - iter 15/157 - loss 45.77906871 - samples/sec: 40.90
# 2019-12-02 05:50:59,456 epoch 1 - iter 30/157 - loss 39.49207792 - samples/sec: 42.71
# 2019-12-02 05:51:11,607 epoch 1 - iter 45/157 - loss 35.91886027 - samples/sec: 39.57
# 2019-12-02 05:51:24,583 epoch 1 - iter 60/157 - loss 33.79157932 - samples/sec: 37.05
# 2019-12-02 07:01:17,949 loading file resources/taggers/example-ner/best-model.pt
# 2019-12-02 07:01:27,758 0.7647	0.7391	0.7517
# 2019-12-02 07:01:27,760
# MICRO_AVG: acc 0.6022 - f1-score 0.7517
# MACRO_AVG: acc 0.2162 - f1-score 0.272025
# Alias-Term tp: 11 - fp: 3 - fn: 9 - tn: 11 - precision: 0.7857 - recall: 0.5500 - accuracy: 0.4783 - f1-score: 0.6471
# Definition tp: 196 - fp: 88 - fn: 92 - tn: 196 - precision: 0.6901 - recall: 0.6806 - accuracy: 0.5213 - f1-score: 0.6853
# Definition-frag tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# Qualifier  tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# Referential-Definition tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# Referential-Term tp: 0 - fp: 2 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# Secondary-Definition tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# Term       tp: 235 - fp: 43 - fn: 44 - tn: 235 - precision: 0.8453 - recall: 0.8423 - accuracy: 0.7298 - f1-score: 0.8438
# 2019-12-02 07:01:27,762 ----------------------------------------------------------------------------------------------------
# Weights plots are saved in resources/taggers/example-ner/weights.png

# %%
# !cp /content/resources/taggers/example-ner/best-model.pt /content/drive/My\ Drive/Task2/

# %%
# load the model you trained
from flair.data import Sentence
model = SequenceTagger.load('/content/drive/My Drive/Task2/best-model.pt')

# create example sentence
sentence = 'Photosynthesis is a process by which plants make food'

# predict tags and print
print(model.predict(sentence))

print(Sentence(sentence).to_tagged_string())
# Out:
# 2020-02-28 12:26:45,928 loading file /content/drive/My Drive/Task2/best-model.pt
# [Sentence: "Photosynthesis is a process by which plants make food" - 9 Tokens]
# Photosynthesis is a process by which plants make food

# %%
data = '''Alias-Term tp: 11 - fp: 3 - fn: 9 - tn: 11 - precision: 0.7857 - recall: 0.5500 - accuracy: 0.4783 - f1-score: 0.6471
Definition tp: 196 - fp: 88 - fn: 92 - tn: 196 - precision: 0.6901 - recall: 0.6806 - accuracy: 0.5213 - f1-score: 0.6853
Definition-frag tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
Qualifier  tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
Referential-Definition tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
Referential-Term tp: 0 - fp: 2 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
Secondary-Definition tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
Term       tp: 235 - fp: 43 - fn: 44 - tn: 235 - precision: 0.8453 - recall: 0.8423 - accuracy: 0.7298 - f1-score: 0.8438'''

import pandas as pd
data = data.split('\n')
data_df = pd.DataFrame([[line.split()[0]]+' '.join(line.split()[1:]).split('-') for line in data])
data_df.head()
# Out:
#                         0         1  ...    8              9
# 0              Alias-Term   tp: 11   ...   f1  score: 0.6471
# 1              Definition  tp: 196   ...   f1  score: 0.6853
# 2         Definition-frag    tp: 0   ...   f1  score: 0.0000
# 3               Qualifier    tp: 0   ...   f1  score: 0.0000
# 4  Referential-Definition    tp: 0   ...   f1  score: 0.0000
#
# [5 rows x 10 columns]

# %%
data_df.drop(8,axis = 1, inplace =True)

# %%
new_col = ['Tag']
for col in range(1,10):
  try:
    new_col.append(data_df[col][0].split()[0])
    data_df[col] = data_df[col].apply(lambda x: float(x.split()[1]))
  except:
    print(col)
data_df.head()
# Out:
# 8
#                         0      1     2     3  ...       5       6       7       9
# 0              Alias-Term   11.0   3.0   9.0  ...  0.7857  0.5500  0.4783  0.6471
# 1              Definition  196.0  88.0  92.0  ...  0.6901  0.6806  0.5213  0.6853
# 2         Definition-frag    0.0   0.0   1.0  ...  0.0000  0.0000  0.0000  0.0000
# 3               Qualifier    0.0   0.0   3.0  ...  0.0000  0.0000  0.0000  0.0000
# 4  Referential-Definition    0.0   0.0   2.0  ...  0.0000  0.0000  0.0000  0.0000
#
# [5 rows x 9 columns]

# %%
data_df.columns =new_col
data_df.head(10)
# Out:
#                       Tag    tp:   fp:  ...  recall:  accuracy:  score:
# 0              Alias-Term   11.0   3.0  ...   0.5500     0.4783  0.6471
# 1              Definition  196.0  88.0  ...   0.6806     0.5213  0.6853
# 2         Definition-frag    0.0   0.0  ...   0.0000     0.0000  0.0000
# 3               Qualifier    0.0   0.0  ...   0.0000     0.0000  0.0000
# 4  Referential-Definition    0.0   0.0  ...   0.0000     0.0000  0.0000
# 5        Referential-Term    0.0   2.0  ...   0.0000     0.0000  0.0000
# 6    Secondary-Definition    0.0   0.0  ...   0.0000     0.0000  0.0000
# 7                    Term  235.0  43.0  ...   0.8423     0.7298  0.8438
#
# [8 rows x 9 columns]

# %%
data_df['support'] = data_df[['tp:','tn:','fp:','fn:']].sum(axis = 1)
data_df.head(10)
# Out:
#                       Tag    tp:   fp:  ...  accuracy:  score:  support
# 0              Alias-Term   11.0   3.0  ...     0.4783  0.6471     34.0
# 1              Definition  196.0  88.0  ...     0.5213  0.6853    572.0
# 2         Definition-frag    0.0   0.0  ...     0.0000  0.0000      1.0
# 3               Qualifier    0.0   0.0  ...     0.0000  0.0000      3.0
# 4  Referential-Definition    0.0   0.0  ...     0.0000  0.0000      2.0
# 5        Referential-Term    0.0   2.0  ...     0.0000  0.0000      5.0
# 6    Secondary-Definition    0.0   0.0  ...     0.0000  0.0000      2.0
# 7                    Term  235.0  43.0  ...     0.7298  0.8438    557.0
#
# [8 rows x 10 columns]

# %%
print("Macro F1")
sum(data_df['score:'])/len(data_df)
# Out:
# Macro F1
# 0.272025

# %%
print("Micro F1")
sum(data_df['score:']*data_df['support'])/sum(data_df['support'])
# Out:
# Micro F1
# 0.7516918367346939

# %%
print("Only considering evaluated tags")
evaluated_tags = [ 'Term', 'Alias-Term','Referential-Term', 'Definition', 'Referential-Definition' ,'Qualifier']
evaluated_indices = [i for i in range(len(data_df)) if data_df['Tag'][i] in evaluated_tags]
print(f"Evaluated indices are {evaluated_indices}")

print("Macro F1")
print(sum(data_df['score:'][evaluated_indices])/len(evaluated_indices))

print("Micro F1")
print(sum(data_df['score:'][evaluated_indices]*data_df['support'][evaluated_indices])/sum(data_df['support'][evaluated_indices]))
# Out:
# Only considering evaluated tags
# Evaluated indices are [0, 1, 3, 4, 5, 7]
# Macro F1
# 0.3627
# Micro F1
# 0.7536143222506394

# %%
crf_str = \
'''         B-Alias-Te-frag      0.000     0.000     0.000         0
            B-Alias-Term      0.700     0.350     0.467        20
            I-Alias-Term      1.000     0.040     0.077        25
         B-Definiti-frag      0.000     0.000     0.000         1
         I-Definiti-frag      0.000     0.000     0.000         2
            B-Definition      0.619     0.552     0.583       288
            I-Definition      0.748     0.891     0.813      4114
             B-Qualifier      0.000     0.000     0.000         3
             I-Qualifier      0.000     0.000     0.000        22
B-Referential-Definition      0.000     0.000     0.000         2
I-Referential-Definition      0.000     0.000     0.000         2
      B-Referential-Term      0.000     0.000     0.000         3
      I-Referential-Term      0.000     0.000     0.000         1
  B-Secondary-Definition      0.000     0.000     0.000         2
  I-Secondary-Definition      0.000     0.000     0.000        14
               B-Te-frag      0.000     0.000     0.000         0
               I-Te-frag      0.000     0.000     0.000         0
                  B-Term      0.777     0.599     0.676       279
                  I-Term      0.753     0.616     0.678       357
    Secondary-Definition      0.000     0.000     0.000         0
              Definition      0.000     0.000     0.000         3
                    Term      0.000     0.000     0.000         0
              Alias-Term      0.000     0.000     0.000         0
               Qualifier      0.000     0.000     0.000         0'''

import pandas as pd
crf_data = crf_str.split('\n')
crf_df = pd.DataFrame([line.split() for line in crf_data])
crf_df.head(10)
# Out:
#                           0      1      2      3     4
# 0           B-Alias-Te-frag  0.000  0.000  0.000     0
# 1              B-Alias-Term  0.700  0.350  0.467    20
# 2              I-Alias-Term  1.000  0.040  0.077    25
# 3           B-Definiti-frag  0.000  0.000  0.000     1
# 4           I-Definiti-frag  0.000  0.000  0.000     2
# 5              B-Definition  0.619  0.552  0.583   288
# 6              I-Definition  0.748  0.891  0.813  4114
# 7               B-Qualifier  0.000  0.000  0.000     3
# 8               I-Qualifier  0.000  0.000  0.000    22
# 9  B-Referential-Definition  0.000  0.000  0.000     2

# %%
crf_df.columns =  ['Tag','precision','recall','f1-score','support']
# crf_df.sort_values('Tag',key=lambda x:x.split('-')[1:])
crf_df.head(30)
# Out:
#                          Tag precision recall f1-score support
# 0            B-Alias-Te-frag     0.000  0.000    0.000       0
# 1               B-Alias-Term     0.700  0.350    0.467      20
# 2               I-Alias-Term     1.000  0.040    0.077      25
# 3            B-Definiti-frag     0.000  0.000    0.000       1
# 4            I-Definiti-frag     0.000  0.000    0.000       2
# 5               B-Definition     0.619  0.552    0.583     288
# 6               I-Definition     0.748  0.891    0.813    4114
# 7                B-Qualifier     0.000  0.000    0.000       3
# 8                I-Qualifier     0.000  0.000    0.000      22
# 9   B-Referential-Definition     0.000  0.000    0.000       2
# 10  I-Referential-Definition     0.000  0.000    0.000       2
# 11        B-Referential-Term     0.000  0.000    0.000       3
# 12        I-Referential-Term     0.000  0.000    0.000       1
# 13    B-Secondary-Definition     0.000  0.000    0.000       2
# 14    I-Secondary-Definition     0.000  0.000    0.000      14
# 15                 B-Te-frag     0.000  0.000    0.000       0
# 16                 I-Te-frag     0.000  0.000    0.000       0
# 17                    B-Term     0.777  0.599    0.676     279
# 18                    I-Term     0.753  0.616    0.678     357
# 19      Secondary-Definition     0.000  0.000    0.000       0
# 20                Definition     0.000  0.000    0.000       3
# 21                      Term     0.000  0.000    0.000       0
# 22                Alias-Term     0.000  0.000    0.000       0
# 23                 Qualifier     0.000  0.000    0.000       0

# %%
for col in crf_df.columns:
  if col == 'Tag':
    continue
  crf_df[col] = crf_df[col].astype('float')

# %%
print("Macro F1")
sum(crf_df['f1-score'])/len(crf_df)
# Out:
# Macro F1
# 0.13725

# %%
print("Micro F1")
sum(crf_df['f1-score']*crf_df['support'])/sum(crf_df['support'])
# Out:
# Micro F1
# 0.7696576488906188

# %%
'''  micro avg      0.740     0.821     0.779      5138
     macro avg      0.192     0.127     0.137      5138
  weighted avg      0.736     0.821     0.770      5138'''.split('\n')
# Out:
# ['     micro avg      0.740     0.821     0.779      5138',
#  '     macro avg      0.192     0.127     0.137      5138',
#  '  weighted avg      0.736     0.821     0.770      5138']

# %% [markdown]
# ## This is what you are looking for!!!!
#
# >NOTE: This section is not complete
#
# >Is Definition == B-Definition/ I-Definition

# %%
print("Only considering evaluated relations")
# evaluated_tags = ['Term', 'Alias-Term', 'Referential-Term', 'Definition', 'Referential-Definition', 'Qualifier']
evaluated_indices_crf = [i for i in range(len(crf_df)) if crf_df['Tag'][i] in evaluated_tags]
evaluated_indices_crf += [i for i in range(len(crf_df)) if crf_df['Tag'][i] in map(lambda x: 'B-'+ x, evaluated_tags)]
evaluated_indices_crf += [i for i in range(len(crf_df)) if crf_df['Tag'][i] in map(lambda x: 'I-'+ x, evaluated_tags)]

print(f"Evaluated indices are {evaluated_indices_crf}")
print(f"Evaluated tags are {[tag for i,tag in enumerate(crf_df['Tag']) if i in evaluated_indices_crf]}")

print("Macro F1")
print(sum(crf_df['f1-score'][evaluated_indices_crf])/len(evaluated_indices_crf))

print("Micro F1")
print(sum(crf_df['f1-score'][evaluated_indices_crf]*crf_df['support'][evaluated_indices_crf])/sum(crf_df['support'][evaluated_indices_crf]))
# Out:
# Only considering evaluated relations
# Evaluated indices are [20, 21, 22, 23, 1, 5, 7, 9, 11, 17, 2, 6, 8, 10, 12, 18]
# Evaluated tags are ['B-Alias-Term', 'I-Alias-Term', 'B-Definition', 'I-Definition', 'B-Qualifier', 'I-Qualifier', 'B-Referential-Definition', 'I-Referential-Definition', 'B-Referential-Term', 'I-Referential-Term', 'B-Term', 'I-Term', 'Definition', 'Term', 'Alias-Term', 'Qualifier']
# Macro F1
# 0.20587499999999997
# Micro F1
# 0.7725143582731002

# %% [markdown]
# > ## Obtained
# `Macro F1: 0.3627` and `Micro F1: 0.7536143222506394`
#
# > ## Previously using CRF
# `Macro F1: 0.20587` and `Micro F1: 0.7725143582731002`
#
# > TO be evaluated: micro avg

# %% [markdown]
# > NOTE:
#
# To be considered: (for evaluation)
#
# 1. Alias Term (B/I)
# 2. Definition (B/I)
# 3. Qualifier (B/I)
# 4. Term (B/I)
# 5. Referential Term (B/I)
# 6. Referential Definition (B/I)
#
# Not to be considered:
#
# 7. Secondary Definition (B/I)[2/14]
# 8. Definiti Frag (B/I) [1/2]
# 9. Te-Frag (B/I) [0]
# 10. Alias-Te-Frag (B) [0]
# 11. Term[0]
# 12. Alias-Term[0]
# 13. Definition[3]
# 14. Qualifier[0]
# 15. Secondary Definition [0]
#
# >[] denotes the number of instances of that particular label
#
# >Since it is too small, we can ignore it as it will effect the micro average too less.
